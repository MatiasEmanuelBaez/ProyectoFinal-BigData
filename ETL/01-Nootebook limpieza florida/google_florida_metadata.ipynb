# %%
import pandas as pd

# %% [markdown]
# # 1

# %%
#importo 
ruta_al_archivo = 'Google/metadata-sitios/1.json'
df1 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')

# %%
df1.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# ...

# %%
conteo_por_cat = df1['state'].value_counts()
print(conteo_por_cat)
# Out:
# state
# Permanently closed                         16731
# Open 24 hours                              14829
# Closed ⋅ Opens 9AM                         12249
# Closed ⋅ Opens 8AM                         11201
# Closed ⋅ Opens 8AM Mon                     10316
#                                            ...
# Closes soon ⋅ 4:30PM ⋅ Opens 7AM Mon           1
# Closes soon ⋅ 6:30PM ⋅ Opens 6:30AM Tue        1
# Closes soon ⋅ 6:30PM ⋅ Opens 6:30AM Sat        1
# Closes soon ⋅ 5PM ⋅ Opens 8:30AM Sat           1
# Closes soon ⋅ 1PM ⋅ Opens 7AM Mon              1
# Name: count, Length: 1918, dtype: int64

# %%
df1['estado'] = df1['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')

# %%
df1 = df1[df1['estado'] == 'FL']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18731 entries, 14 to 274932
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              18731 non-null  object
#  1   address           18731 non-null  object
#  2   gmap_id           18731 non-null  object
#  3   description       874 non-null    object
#  4   latitude          18731 non-null  float64
#  5   longitude         18731 non-null  float64
#  6   category          18565 non-null  object
#  7   avg_rating        18731 non-null  float64
#  8   num_of_reviews    18731 non-null  int64
#  9   price             924 non-null    object
#  10  hours             13821 non-null  object
#  11  MISC              14108 non-null  object
#  12  state             13962 non-null  object
#  13  relative_results  16189 non-null  object
#  14  url               18731 non-null  object
#  15  estado            18731 non-null  object
# ...

# %%
df1_exploded = df1.explode('category')

# Luego, obtén los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df1_exploded['category'].unique().tolist()

# %%
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2

# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
# Out:
# ['Corporate office', 'Cruise agency', None, 'Barber shop', 'Family practice physician', 'General practitioner', 'Restaurant', 'Buffet restaurant', 'Mailing service', 'Courier service', 'Fax service', 'Lamination service', 'Mailbox rental service', 'Notary public', 'Packaging supply store', 'Post office', 'Shipping service', 'Pediatrician', "Children's hospital", 'Doctor', 'Tax preparation service', 'Accountant', 'Payroll service', 'Air conditioning system supplier', 'Air filter supplier', 'Commercial refrigerator supplier', 'Distribution service', 'Heating equipment supplier', 'Wholesaler', 'Hair salon', 'Locksmith', 'Laundromat', 'Produce wholesaler', 'Cooperative', 'Physical therapy clinic', 'Flooring store', 'Bakery', 'Deli', 'Boat builders', 'Boat dealer', 'Clothing store', 'Real estate developer', 'Logistics service', 'Warehouse', 'Real estate agency', "Women's clothing store", 'Boutique', 'Dress store', 'Gift shop', 'Transportation service', 'Bus charter', 'Trucking company', '
# ...

# %%
print(segunda_mitad)
# Out:
# ['Truck dealer', 'Jeans shop', 'Optical wholesaler', 'Police department', 'Fish & chips restaurant', 'Car battery store', 'Camp', 'Public parking space', 'Free parking lot', 'Food manufacturer', 'Spanish restaurant', 'Business networking company', 'Sofa store', 'Volunteer organization', 'Food products supplier', 'House cleaning service', 'BMW dealer', 'Engine rebuilding service', 'Jaguar dealer', 'Land Rover dealer', 'Lexus dealer', 'Toyota dealer', 'Nursery school', 'Veterans affairs department', 'Airline ticket agency', 'Fingerprinting service', 'Historical place', 'Wildlife park', 'Plasterer', 'Frozen yogurt shop', 'House sitter', 'Fence supply store', 'Garden furniture shop', 'Ready mix concrete supplier', 'Topsoil supplier', 'Fire station', 'Snow removal service', 'Bike sharing station', 'Martial arts supply store', 'Taekwondo school', 'Crane rental agency', 'Southern restaurant (US)', 'Sports equipment rental service', 'Agricultural service', 'Customs broker', 'Shipping equipme
# ...

# %%
categorias_gastronomicas_filtradas = [
    'Restaurant', 'Buffet restaurant', 'Bakery', 'Deli', 'Coffee shop',
    'Cafe', 'Modern French restaurant', 'Grocery store', 'Liquor store',
    'Bar', 'Beer store', 'Winery', 'Bar & grill', 'Juice shop', 'Ice cream shop',
    'Fast food restaurant', 'American restaurant', 'Pizza restaurant', 'Indian restaurant',
    'Sushi restaurant', 'Mediterranean restaurant', 'Pizza delivery', 'Pizza Takeout',
    'Fast food restaurant', 'Wine bar', 'Breakfast restaurant', 'Dinner theater',
    'Fine dining restaurant', 'Mexican restaurant', 'Peruvian restaurant', 'Salad shop',
    'Tea house', 'Family restaurant', 'Taco restaurant', 'Chicken restaurant',
    'Seafood restaurant', 'Cajun restaurant', 'Chicken wings restaurant', 'Steak house',
    'Hamburger restaurant', 'Fish & chips restaurant', 'Food manufacturer', 'Spanish restaurant',
    'Sushi takeaway', 'Pretzel store', 'Wedding photographer', 'Bistro', 'Pasta shop',
    'Latin American restaurant', 'Mobile caterer', 'Beer garden', 'Brewery', 'Brunch restaurant',
    'Live music bar', 'Bikram yoga studio', 'Candy store', 'Cocktail bar', 'Sushi restaurant',
    'Ice cream shop', 'Pizza delivery', 'Ice cream truck', 'Juice shop', 'Sandwich shop',
    'Bagel shop', 'Donut shop', 'Deli', 'Food truck', 'Breakfast restaurant', 'Bakery',
    'Coffee shop', 'Tea house', 'Smoothie shop', 'Juice bar', 'Diner', 'Cafeteria',
    'Coffee roasters', 'Hot dog restaurant', 'Creole restaurant', 'Belgian restaurant',
    'Turkish restaurant', 'Brazilian restaurant', 'Brewpub', 'Brazilian pastelaria', 'BBQ restaurant',
    'Asian fusion restaurant', 'Japanese restaurant', 'Japanese steakhouse', 'Vietnamese restaurant',
    'Chinese restaurant', 'Thai restaurant', 'Korean restaurant', 'Indian restaurant',
    'Pakistani restaurant', 'South Asian restaurant', 'Afghan restaurant', 'Middle Eastern restaurant',
    'Halal restaurant', 'Lebanese restaurant', 'Mediterranean restaurant', 'Greek restaurant',
    'Northern Italian restaurant', 'Italian restaurant', 'Southern Italian restaurant',
    'Pizza restaurant', 'French restaurant', 'Irish restaurant', 'German restaurant', 'Spanish restaurant',
    'Portuguese restaurant', 'Caribbean restaurant', 'Soul food restaurant', 'Southern restaurant (US)',
    'Cajun restaurant', 'Creole restaurant', 'Mexican restaurant', 'Salvadoran restaurant',
    'Honduran restaurant', 'Guatemalan restaurant', 'Nicaraguan restaurant', 'Peruvian restaurant',
    'Colombian restaurant', 'Venezuelan restaurant', 'Argentine restaurant', 'Brazilian restaurant',
    'Chilean restaurant', 'Uruguayan restaurant', 'Cuban restaurant', 'Jamaican restaurant',
    'Haitian restaurant', 'Dominican restaurant', 'Puerto Rican restaurant', 'African restaurant',
    'Ethiopian restaurant', 'Moroccan restaurant', 'Egyptian restaurant', 'Libyan restaurant',
    'Sudanese restaurant', 'Nigerian restaurant', 'South African restaurant', 'American restaurant',
    'Canadian restaurant', 'Australian restaurant', 'New Zealand restaurant', 'British restaurant',
    'Scottish restaurant', 'Irish restaurant', 'Welsh restaurant', 'Scandinavian restaurant',
    'Russian restaurant', 'Ukrainian restaurant', 'Polish restaurant', 'Hungarian restaurant',
    'Czech restaurant', 'Slovak restaurant', 'Austrian restaurant', 'Swiss restaurant', 'German restaurant',
    'Dutch restaurant', 'Belgian restaurant', 'French restaurant', 'Italian restaurant', 'Spanish restaurant',
    'Portuguese restaurant', 'Greek restaurant', 'Turkish restaurant', 'Middle Eastern restaurant',
    'Iranian restaurant', 'Afghan restaurant', 'Pakistani restaurant', 'Indian restaurant',
    'Bangladeshi restaurant', 'Nepalese restaurant', 'Sri Lankan restaurant', 'Southeast Asian restaurant',
    'Burmese restaurant', 'Thai restaurant', 'Laotian restaurant', 'Cambodian restaurant', 'Vietnamese restaurant',
    'Malaysian restaurant', 'Indonesian restaurant', 'Filipino restaurant', 'Singaporean restaurant',
    'Bruneian restaurant', 'Chinese restaurant', 'Japanese restaurant', 'Korean restaurant', 'Mongolian restaurant',
    'Tibetan restaurant', 'Bhutanese restaurant', 'Taiwanese restaurant', 'Hong Kong-style restaurant',
    'Macanese restaurant', 'American Chinese restaurant', 'Canadian Chinese restaurant', 'British Chinese restaurant',
    'Australian Chinese restaurant', 'New Zealand Chinese restaurant', 'European restaurant', 'French restaurant',
    'Italian restaurant', 'Spanish restaurant', 'Portuguese restaurant', 'German restaurant', 'Dutch restaurant',
    'Belgian restaurant', 'British restaurant', 'Irish restaurant', 'Eastern European restaurant', 'Russian restaurant',
    'Ukrainian restaurant', 'Polish restaurant', 'Czech restaurant', 'Slovak restaurant', 'Hungarian restaurant',
    'Austrian restaurant', 'Swiss restaurant', 'Scandinavian restaurant', 'Finnish restaurant', 'Swedish restaurant',
    'Norwegian restaurant', 'Danish restaurant', 'Icelandic restaurant', 'Balkan restaurant', 'Romanian restaurant',
    'Bulgarian restaurant', 'Serbian restaurant', 'Croatian restaurant', 'Bosnian restaurant', 'Montenegrin restaurant',
    'Albanian restaurant', 'Greek restaurant', 'Turkish restaurant', 'Middle Eastern restaurant', 'Iranian restaurant',
    'Afghan restaurant', 'Pakistani restaurant', 'Indian restaurant', 'Bangladeshi restaurant', 'Nepalese restaurant',
    'Sri Lankan restaurant', 'Middle Eastern restaurant', 'Iranian restaurant', 'Afghan restaurant', 'Pakistani restaurant',
    'Indian restaurant', 'Bangladeshi restaurant', 'Nepalese restaurant', 'Sri Lankan restaurant', 'Southeast Asian restaurant',
    'Burmese restaurant', 'Thai restaurant', 'Laotian restaurant', 'Cambodian restaurant', 'Vietnamese restaurant',
    'Malaysian restaurant', 'Indonesian restaurant', 'Filipino restaurant', 'Singaporean restaurant', 'Bruneian restaurant',
    'Chinese restaurant', 'Japanese restaurant', 'Korean restaurant', 'Mongolian restaurant', 'Tibetan restaurant',
    'Bhutanese restaurant', 'Taiwanese restaurant', 'Hong Kong-style restaurant', 'Macanese restaurant',
    'American Chinese restaurant', 'Canadian Chinese restaurant', 'British Chinese restaurant', 'Australian Chinese restaurant',
    'New Zealand Chinese restaurant', 'African restaurant', 'Ethiopian restaurant', 'Moroccan restaurant', 'Egyptian restaurant',
    'Libyan restaurant', 'Sudanese restaurant', 'Nigerian restaurant', 'South African restaurant', 'American restaurant',
    'Canadian restaurant', 'Australian restaurant', 'New Zealand restaurant', 'British restaurant', 'Scottish restaurant',
    'Irish restaurant', 'Welsh restaurant', 'Scandinavian restaurant', 'Russian restaurant', 'Ukrainian restaurant',
    'Polish restaurant', 'Hungarian restaurant', 'Czech restaurant', 'Slovak restaurant', 'Austrian restaurant',
    'Swiss restaurant', 'German restaurant', 'Dutch restaurant', 'Belgian restaurant', 'French restaurant',
    'Italian restaurant', 'Spanish restaurant', 'Portuguese restaurant', 'Greek restaurant', 'Turkish restaurant',
    'Middle Eastern restaurant', 'Iranian restaurant', 'Afghan restaurant', 'Pakistani restaurant', 'Indian restaurant',
    'Bangladeshi restaurant', 'Nepalese restaurant', 'Sri Lankan restaurant'
]

# %%
df1 = df1.dropna(subset=['category']).loc[df1['category'].astype(bool)]

# %%
filtered_df1_1 = df1[df1['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]

# %%
filtered_df1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1193 entries, 114 to 274112
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1193 non-null   object
#  1   address           1193 non-null   object
#  2   gmap_id           1193 non-null   object
#  3   description       230 non-null    object
#  4   latitude          1193 non-null   float64
#  5   longitude         1193 non-null   float64
#  6   category          1193 non-null   object
#  7   avg_rating        1193 non-null   float64
#  8   num_of_reviews    1193 non-null   int64
#  9   price             275 non-null    object
#  10  hours             1010 non-null   object
#  11  MISC              1154 non-null   object
#  12  state             1012 non-null   object
#  13  relative_results  808 non-null    object
#  14  url               1193 non-null   object
#  15  estado            1193 non-null   object
# ...

# %%
df1_filtered = filtered_df1_1.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
df1_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1193 entries, 114 to 274112
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1193 non-null   object
#  1   address         1193 non-null   object
#  2   gmap_id         1193 non-null   object
#  3   latitude        1193 non-null   float64
#  4   longitude       1193 non-null   float64
#  5   category        1193 non-null   object
#  6   avg_rating      1193 non-null   float64
#  7   num_of_reviews  1193 non-null   int64
#  8   MISC            1154 non-null   object
#  9   state           1012 non-null   object
#  10  estado          1193 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 111.8+ KB

# %% [markdown]
# # 2

# %%
#importo 
ruta_al_archivo = 'Google/metadata-sitios/2.json'
df2 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
df2['estado'] = df2['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
df2 = df2[df2['estado'] == 'FL']
df2_exploded = df2.explode('category')
# Luego, obtén los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df2_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
print(segunda_mitad)
# Out:
# ['Acupuncture clinic', 'Acupuncturist', 'Chinese medicine clinic', 'Herbal medicine store', 'Holistic medicine practitioner', 'Pain control clinic', 'Pain management physician', 'Wellness center', 'Gated community', 'Real estate agency', 'Drug store', 'Convenience store', 'Cosmetics store', 'Doctor', 'Massage therapist', 'Car dealer', 'Mortgage lender', 'Mortgage broker', 'Pressure washing service', 'Millwork shop', 'Gas station', 'Orthopedic surgeon', 'Hand surgeon', 'Family practice physician', 'Medical clinic', 'Medical spa', 'Rehabilitation center', 'Cell phone store', 'Cell phone accessory store', 'Computer repair service', 'Data recovery service', 'Electronics repair shop', 'Phone repair service', 'Used game store', 'Real estate consultant', 'Hamburger restaurant', 'Restaurant', 'Park & ride', 'Psychic', 'Consultant', 'Dental clinic', 'Propane supplier', 'Consignment shop', 'Neurosurgeon', 'Internist', 'Building materials store', 'Building materials supplier', 'Construction mat
# ...

# %%
rubro_gastronomico1 = ['Hamburger restaurant', 'Restaurant', 'Cuban restaurant', 'Mexican restaurant', 'Variety store', 'Hot dog restaurant', 'Hot dog stand', 'Seafood restaurant', 'Pizza restaurant', 'Pizza Takeout', 'American restaurant', 'Breakfast restaurant', 'Brunch restaurant', 'Chinese restaurant', 'Fast food restaurant', 'Takeout Restaurant', 'Vegetarian restaurant', 'Motel', 'Ice cream shop', 'Sandwich shop', 'Fast food restaurant', 'Takeout Restaurant', 'Coffee shop', 'Coffee store', 'Bakery',  'Cafe', 'Mediterranean restaurant', 'Vegan restaurant', 'Cake shop', 'Dessert shop', 'Wedding bakery', 'Buffet restaurant', 'Deli', 'Candy store', 'Cupcake shop', 'Juice shop', 'Frozen dessert supplier', 'Peruvian restaurant', 'Tapas bar', 'Tapas restaurant', 'Taco restaurant', 'Tex-Mex restaurant', 'Brazilian restaurant', 'Steak house', 'Burger Restaurant', 'Smoothie shop', 'Donut shop', 'Cupcake shop', 'Dessert restaurant', 'Soul food restaurant', 'Barbecue restaurant', 'Bistro', 'Wine bar', 'European restaurant']

# %%
gastronomic_keywords = [
    'Venezuelan restaurant', 'Salsa classes', 'Fireplace store', 'Asian restaurant',
    'Sushi restaurant', 'Organic restaurant', 'Pizza delivery', 'Pizza takeout',
    'Salad shop', 'Juice shop', 'Juice manufacturer', 'Organic restaurant',
    'Pizza delivery', 'Pizza takeout', 'Salad shop', 'Candy store', 'Candy wholesaler',
    'Convenience store', 'Donut shop', 'Convenience store', 'Donut shop', 'Yogurt shop',
    'Ice cream shop', 'Ice cream manufacturer', 'Ice cream shop', 'Italian restaurant',
    'French restaurant', 'German restaurant', 'American restaurant', 'Mexican restaurant',
    'Chinese restaurant', 'Japanese restaurant', 'Korean restaurant', 'Thai restaurant',
    'Vietnamese restaurant', 'Indian restaurant', 'Mediterranean restaurant',
    'Middle Eastern restaurant', 'Greek restaurant', 'Brazilian restaurant',
    'Peruvian restaurant', 'Argentinian restaurant', 'Chilean restaurant',
    'Spanish restaurant', 'British restaurant', 'South Asian restaurant',
    'Raw food restaurant', 'Nicaraguan restaurant', 'Continental restaurant',
    'Nicaraguan restaurant', 'Continental restaurant', 'Argentinian restaurant',
    'Brazilian restaurant', 'Italian restaurant', 'French restaurant',
    'South Asian restaurant', 'Raw food restaurant', 'Spanish restaurant',
    'Nicaraguan restaurant', 'Raw food restaurant', 'South Asian restaurant',
    'Nuevo Latino restaurant'
]

# %%
categorias_gastronomicas_filtradas=rubro_gastronomico1+gastronomic_keywords
df2= df2.dropna(subset=['category']).loc[df2['category'].astype(bool)]
filtered_df2 = df2[df2['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df2 = filtered_df2.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %% [markdown]
# # 3

# %%
#importo 
ruta_al_archivo = 'Google/metadata-sitios/3.json'
df3 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
df3['estado'] = df3['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
df3 = df3[df3['estado'] == 'FL']
df3_exploded = df3.explode('category')
# Luego, obtén los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df3_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
# Out:
# ['Hotel', 'Doctor', 'Orthopedic surgeon', 'Caterer', 'BBQ area', 'Mobile caterer', 'Restaurant', 'Chiropractor', 'Copy shop', 'Banner store', 'Business to business service', 'Copying supply store', 'Custom label printer', 'Mailing service', 'Packaging supply store', 'Print shop', 'Sign shop', "Women's clothing store", 'Gastroenterologist', 'Medical supply store', 'Tennis club', 'Church', 'Association or organization', 'Bus stop', 'Baptist church', 'Medical diagnostic imaging center', 'Pregnancy care center', 'Medical group', 'County government office', 'Concrete contractor', 'Car dealer', 'Furniture store', 'Bed shop', 'Mattress store', 'Mediation service', 'Adoption agency', 'Divorce lawyer', 'Family law attorney', 'Attorney', 'Home builder', 'Housing development', 'Non-denominational church', 'Used book store', 'Art gallery', 'Gift shop', 'Property management company', 'Condominium rental agency', 'Real estate agency', 'Real estate agents', 'Insurance agency', 'Pet groomer', 'Canna
# ...

# %%
categorias_gastronomicas1 = ['Restaurant', 'Caterer', 'BBQ area', 'Mobile caterer', 'Bakery', 'Seafood restaurant', 
                            'Spanish restaurant', 'Donut shop', 'Dessert shop', 'Tea house', 'Gluten-free restaurant', 
                            'Tea store', 'Pub', 'Anglican church', 'Episcopal church', 'Sushi restaurant', 'Cake shop', 
                            'Salvadoran restaurant', 'Vegetarian restaurant', 'Coffee shop', 'Latin American restaurant', 
                            'Venezuelan restaurant', 'Juice shop', 'Takeout Restaurant', 'Sandwich shop', 'Italian restaurant', 
                            'Pizza delivery', 'Pizza restaurant', 'Frozen yogurt shop', 'Dive shop', 'SCUBA instructor', 
                            'SCUBA tour agency', 'Japanese restaurant', 'Chicken wings restaurant', 'Pizza Takeout', 'Salad shop', 
                            'American restaurant', 'Fast food restaurant', 'Hot dog stand', 'Coffee store', 'Breakfast restaurant', 
                            'Lunch restaurant', 'Bakery', 'Bistro', 'Cafe', 'Food delivery service']

# %%
print(segunda_mitad)
# Out:
# ['Investment company', 'Ship building', 'Western apparel store', 'Body shaping class', 'Industrial chemicals wholesaler', 'Swimwear store', 'Bagel shop', 'Wetland', 'Hiking area', 'Aromatherapy service', 'Lymph drainage therapist', 'Meditation center', 'Fishing store', 'Property maintenance', 'Curtain and upholstery cleaning service', 'Siding contractor', 'Sunroom contractor', 'Industrial design company', 'Drafting service', 'Machining manufacturer', 'Cabin rental agency', 'Cell phone accessory store', 'Hair care', 'Wedding bakery', 'Company', 'Auto machine shop', 'Office equipment supplier', 'Copier repair service', 'Photocopiers supplier', 'Telephone exchange', 'Dock builder', 'Endocrinologist', 'Dental supply store', 'Mechanical contractor', 'Fishing pier', 'Nurse practitioner', 'Beach clothing store', 'Sanitation service', 'Tree farm', 'Hobby store', 'Drone shop', 'Training centre', 'Fire alarm supplier', 'Fire protection consultant', 'Fire protection service', 'Fire protection s
# ...

# %%
categorias_gastronomicas = ['Bagel shop', 'Wedding bakery', 'Fishing store', 'Cookie shop', 'Market', 'Hot dog restaurant', 'Grocery delivery service', 'Candy store', 'Chocolate shop', 'Confectionery wholesaler', 'Balloon artist', 'Doughnut shop', 'Cake decorating supply shop', 'Dessert shop', 'Ice cream shop', 'Frozen yogurt shop', 'Cheese shop', 'Butcher shop', 'Seafood market', 'Bakery', 'Beverage distributor', 'Cocktail bar', 'Cafe', 'Restaurant', 'Brewery', 'Sake brewery', 'Wine bar', 'Sushi takeaway', 'Taco restaurant', 'Diner', 'Juice shop', 'Smoothie shop', 'Tea store', 'Coffee stand', 'Coffee wholesaler', 'Coffee machine supplier', 'Bistro', 'Cupcake shop', 'Pancake restaurant', 'Bottle shop', 'Brewpub', 'Soup shop', 'French steakhouse restaurant', 'Bikram yoga studio', 'Aquarium shop', 'Confectionery', 'Dim sum restaurant', 'Burrito restaurant']

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df3= df3.dropna(subset=['category']).loc[df3['category'].astype(bool)]
filtered_df3 = df3[df3['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df3 = filtered_df3.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %% [markdown]
# # 4

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/4.json'
df4 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df4['estado'] = df4['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df4 = df4[df4['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df4_exploded = df4.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df4_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
# Out:
# ['Auto insurance agency', 'Health insurance agency', 'Home insurance agency', 'Insurance agency', 'Life insurance agency', 'Motorcycle insurance agency', 'Auto repair shop', 'High school', 'Private educational institution', 'Home builder', 'Real estate agents', 'Real estate consultant', 'Personal injury attorney', 'Picture frame shop', 'Real estate agency', 'Dentist', 'Doctor', 'Oncologist', 'Internist', 'Emergency room', 'Market researcher', 'Bus stop', 'Beauty salon', 'Nail salon', 'Infectious disease physician', 'Tobacco shop', 'Consignment shop', 'Vintage clothing store', "Women's clothing store", 'Shoe store', 'Clothing store', 'Apartment complex', 'Cafe', 'Store', 'Plant nursery', 'Parking garage', None, 'Hair salon', 'Skin care clinic', 'Tax preparation service', 'Accountant', 'Tax consultant', 'Tax preparation', 'Gas station', 'Religious organization', 'Office', 'Airline', 'Pet groomer', 'Parking lot', 'Auto parts store', 'Garbage collection service', 'Crushed stone supplier'
# ...

# %%
categorias_gastronomicas = [
    'Sushi restaurant', 'Restaurant', 'Bar', 'Dessert restaurant', 'Ice cream shop',
    'Cafe', 'Bakery', 'Pizza restaurant', 'Fast food restaurant', 'Breakfast restaurant',
    'Coffee shop', 'Sandwich shop', 'Juice shop', 'Vegan restaurant', 'Hamburger restaurant',
    'Donut shop', 'Bagel shop', 'Pastry shop', 'Snack bar', 'Frozen yogurt shop',
    'BBQ restaurant', 'Mediterranean restaurant', 'Greek restaurant', 'Kebab shop',
    'Middle Eastern restaurant', 'Turkish restaurant', 'Vegetarian restaurant', 'Bistro',
    'Gourmet grocery store', 'Fine dining restaurant', 'Gluten-free restaurant',
    'Small plates restaurant', 'Tapas restaurant', 'Wine cellar', 'Wine club',
    'Catering food and drink supplier', 'Food court', 'Pub', 'African goods store'
]

# %%
print(segunda_mitad)
# Out:
# ['Outdoor sports store', 'Collectibles store', 'Glassware store', 'Painting lessons', 'Rustic furniture store', 'Cabinet store', 'Kitchen supply store', 'Laminating equipment supplier', 'Plywood supplier', 'Upholstery cleaning service', 'Computer training school', 'College', 'Software training institute', 'Beverage distributor', 'Party planner', 'Kosher restaurant', 'Commercial refrigeration', 'English language school', 'Pharmaceutical company', 'Art cafe', 'Pottery store', 'Agricultural production', 'Agricultural service', 'Fruit and vegetable store', 'Honey farm', 'Pumping equipment and service', 'Water softening equipment supplier', 'ATV repair shop', 'Venezuelan restaurant', 'Truck parts supplier', 'Presbyterian church', 'Steak house', 'Sports card store', 'Vacuum cleaning system supplier', 'Security guard service', 'Historical landmark', 'Construction and maintenance office', 'Boxing club', 'Açaí shop', 'Social club', 'Safe & vault shop', 'Arts organization', 'Spice store', 'Foo
# ...

# %%
categorias_gastronomicas1 = [
    'Sushi restaurant', 'Restaurant', 'Dessert restaurant', 'Ice cream shop',
    'Cafe', 'Bakery', 'Pizza restaurant', 'Fast food restaurant', 'Breakfast restaurant',
    'Coffee shop', 'Sandwich shop', 'Juice shop', 'Vegan restaurant', 'Hamburger restaurant',
    'Donut shop', 'Bagel shop', 'Pastry shop', 'Snack bar', 'Frozen yogurt shop',
    'BBQ restaurant', 'Mediterranean restaurant', 'Greek restaurant', 'Kebab shop',
    'Middle Eastern restaurant', 'Turkish restaurant', 'Vegetarian restaurant', 'Bistro',
    'Gourmet grocery store', 'Fine dining restaurant', 'Gluten-free restaurant',
    'Small plates restaurant', 'Tapas restaurant', 'Wine cellar', 'Wine club',
    'Catering food and drink supplier', 'Food court', 'African goods store'
]

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df4= df4.dropna(subset=['category']).loc[df4['category'].astype(bool)]
filtered_df4 = df4[df4['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df4 = filtered_df4.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %% [markdown]
# # 5

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/5.json'
df5 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df5['estado'] = df5['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df5 = df5[df5['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df5_exploded = df5.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df5_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
# Out:
# ['Vaporizer store', 'Beauty salon', 'Hair salon', 'Peninsula', 'Auto repair shop', 'Motorcycle parts store', 'ATV repair shop', 'Motorcycle repair shop', 'Hardware store', 'Park', 'Auto body shop', 'Vehicle shipping agent', 'Freight forwarding service', 'Mover', 'Vehicle exporter', 'Insurance agency', 'Meat packer', 'Painter', 'Record store', 'Family practice physician', 'Car repair and maintenance', 'Religious organization', 'Employment agency', 'Surf shop', 'Apartment building', 'Apartment complex', 'Dentist', 'Cosmetic dentist', 'Dental implants periodontist', 'Psychic', 'Candle store', 'Mediation service', 'Spa', 'Nursing school', 'Bank', 'Financial consultant', 'Financial planner', 'Consultant', 'Day care center', 'Learning center', 'Jewelry store', 'Electronics store', 'Jeweler', 'Jewelry repair service', 'Musical instrument store', 'Pawn shop', 'Sporting goods store', 'Tool store', 'Tax preparation service', 'Hair extensions supplier', 'Beauty product supplier', 'Wig shop', 'U
# ...

# %%
categorias_gastronomicas = [
    'Mexican restaurant', 'Fast food restaurant', 'Takeout Restaurant', 'Restaurant', 'Sushi restaurant',
    'Japanese restaurant', 'Cafe', 'Coffee shop', 'Convenience store',  
     'Grocery store', 'Barbecue restaurant',
    'Deli', 'Cafeteria', 'Caribbean restaurant', 'Mexican grocery store', 'Fastener supplier', 'Ice cream shop',
    'Takeout Restaurant', 'Cuban restaurant', 'Indian restaurant', 'Asian restaurant',
    'Halal restaurant', 'Chinese restaurant', 'Italian restaurant', 'Sports bar',
    'Dessert restaurant', 'Frozen dessert supplier', 'Frozen yogurt shop', 'Juice shop', 'Wine bar', 'Brewery',
    'Brunch restaurant', 'Cookie shop', 'Tapas bar', 'Tapas restaurant', 'Southern restaurant (US)',
    'Spanish restaurant', 'Tapas bar', 'Tapas restaurant', 'Southern restaurant (US)',
    'Mexican restaurant', 'Takeout Restaurant'
]

# %%
print(segunda_mitad)
# Out:
# ['Library', 'Research institute', 'Building design company', 'Episcopal church', 'Stadium', 'Land surveyor', 'Food and drink', 'Public wheelchair-accessible bathroom', 'Golf club', 'Funeral director', 'Adoption agency', 'Fax service', 'Immigration & naturalization service', 'Resume service', 'Typing service', 'Hostel', 'Plumbing supply store', 'Animal feed store', 'Convention center', 'Futon store', 'Railroad company', 'Produce wholesaler', 'Hot tub repair service', 'Call center', 'Car racing track', 'Auction house', 'Used musical instrument store', 'Play school', "Children's party service", 'Packaging company', 'Lutheran church', 'Wholesale bakery', 'Clock repair service', 'Notable street', 'Golf cart dealer', 'RV dealer', 'Used truck dealer', 'Breakfast restaurant', 'Building inspector', 'Decal supplier', 'Photography service', 'Fishing store', 'Mediterranean restaurant', 'Alternative fuel station', 'Food and beverage exporter', 'Employment search service', 'Youth social services o
# ...

# %%
categorias_gastronomicas1=['Breakfast restaurant', 'Mediterranean restaurant', 'Alternative fuel station', 'Food and beverage exporter', 'Futon store', 'Gourmet grocery store', 'Cafeteria',
 'Cajun restaurant', 'Bakery', 'Brazilian restaurant', 'Tea manufacturer', 'Spices wholesalers', 'Tea wholesaler',
 'Meat processor', 'Gastropub', 'Creole restaurant', 'Po’ boys restaurant', 'Vietnamese restaurant', 'Bagel shop',
 'Coffee roasters', 'Argentinian restaurant', 'South American restaurant', 'Middle Eastern restaurant', 'Soup restaurant',
 'Food court', 'Breakfast restaurant', 'Sweets and dessert buffet', 'Wedding bakery', 'Seafood market',
 'Soup restaurant', 'Wildlife refuge', 'Juice shop', 'Vegetarian restaurant', 'Donut shop', 'Fishing pond', 'Grill store',
 'Dairy farm', 'Asian fusion restaurant', 'Buffet restaurant', 'Home audio store', 'Home theater store', 'Stereo repair service',
 'Wedding chapel', 'French restaurant', 'Organic restaurant']

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df5= df5.dropna(subset=['category']).loc[df5['category'].astype(bool)]
filtered_df5 = df5[df5['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df5 = filtered_df5.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
filtered_df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1474 entries, 507 to 274655
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1474 non-null   object
#  1   address         1474 non-null   object
#  2   gmap_id         1474 non-null   object
#  3   latitude        1474 non-null   float64
#  4   longitude       1474 non-null   float64
#  5   category        1474 non-null   object
#  6   avg_rating      1474 non-null   float64
#  7   num_of_reviews  1474 non-null   int64
#  8   MISC            1422 non-null   object
#  9   state           1275 non-null   object
#  10  estado          1474 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 138.2+ KB

# %% [markdown]
# # 6

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/6.json'
df6 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df6['estado'] = df6['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df6 = df6[df6['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df6_exploded = df6.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df6_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
# Out:
# ['Transportation escort service', 'Delivery service', 'Storage facility', 'Real estate agency', 'Car detailing service', 'Car wash', 'Laser hair removal service', 'Book store', 'Gift shop', 'Gift wrap store', 'Souvenir store', 'Video duplication service', 'Car rental agency', 'Bicycle rental service', 'Scooter rental service', 'Church of the Nazarene', 'Massage therapist', 'Foot massage parlor', 'Lymph drainage therapist', 'Massage spa', 'Reflexologist', 'Post office', 'Logistics service', 'Money order service', 'Shipping and mailing service', 'Title company', 'Ophthalmologist', 'Doctor', 'State government office', 'Chiropractor', 'Dance school', 'Ballet school', "Children's party service", 'Dance company', 'DJ service', 'Drama school', 'Event venue', 'Cell phone store', 'Telecommunications service provider', 'Insurance agency', 'Auto insurance agency', 'Home insurance agency', 'Life insurance agency', "Renter's insurance agency", 'Auto repair shop', 'Accountant', 'Military base', 'S
# ...

# %%
categorias_gastronomicas1= ['Asian restaurant', 'Ice cream shop', 'Chinese restaurant', 'Sandwich shop', 'Bakery', 'Coffee shop',
 'Pizza restaurant', 'Fast food restaurant', 'Sushi restaurant', 'Mexican restaurant', 'Italian restaurant', 'Seafood restaurant',
 'Thai restaurant', 'Indian restaurant', 'Mediterranean restaurant', 'Vegetarian restaurant', 'Vegan restaurant', 'Greek restaurant',
 'French restaurant', 'Spanish restaurant', 'German restaurant', 'Brazilian restaurant', 'Argentinian restaurant', 'Peruvian restaurant',
 'Steak house', 'Barbecue restaurant', 'American restaurant', 'New American restaurant', 'Southern restaurant', 'Cajun restaurant',
 'Diner', 'Breakfast restaurant', 'Brunch restaurant', 'Buffet restaurant', 'Food court', 'Cafeteria', 'Irish pub', 'English restaurant',
 'Scottish restaurant', 'Pub', 'Brewpub', 'Wine bar', 'Cocktail bar', 'Sports bar', 'Juice shop', 'Smoothie shop', 'Tea house']

# %%
print(segunda_mitad)
# Out:
# ['Auction house', 'SCUBA tour agency', 'Dive shop', 'Portrait studio', 'Internet service provider', 'Cable company', 'Episcopal church', 'Gay sauna', 'Pipe supplier', 'Auto accessories wholesaler', 'Car alarm supplier', 'Jazz club', 'Shelving store', 'Music instructor', 'Music store', 'Video game store', 'Homeless service', 'Youth social services organization', 'Midwife', 'Sailmaker', 'Herbal medicine store', 'Computer software store', 'Driveshaft shop', 'Visa and passport office', 'Call center', 'Commercial cleaning service', 'Pakistani restaurant', 'Bangladeshi restaurant', 'Indian restaurant', 'Supermarket', 'Market', 'Asian grocery store', 'Cultural center', 'Fried chicken takeaway', 'Boot camp', 'Wildlife rescue service', 'Zoo', 'Australian restaurant', 'Gluten-free restaurant', 'Funeral home', 'Cremation service', 'Psychiatrist', 'Psychotherapist', 'Business park', 'Recording studio', 'Light bulb supplier', 'RV supply store', 'Reform synagogue', 'Synagogue', 'Foot care', 'Charc
# ...

# %%
categorias_gastronomicas=['Pakistani restaurant', 'Bangladeshi restaurant', 'Indian restaurant', 'Asian grocery store',
 'Fried chicken takeaway', 'Sushi restaurant', 'Thai restaurant', 'Italian restaurant', 'Mexican restaurant', 'Pizza restaurant',
 'Bakery', 'Coffee shop', 'Ice cream shop', 'Chinese restaurant', 'Fast food restaurant', 'Mediterranean restaurant',
 'Vegetarian restaurant', 'Vegan restaurant', 'Greek restaurant', 'French restaurant', 'Spanish restaurant', 'German restaurant',
 'Brazilian restaurant', 'Argentinian restaurant', 'Peruvian restaurant', 'Steak house', 'Barbecue restaurant', 'American restaurant',
 'New American restaurant', 'Southern restaurant', 'Cajun restaurant', 'Diner', 'Breakfast restaurant', 'Brunch restaurant',
 'Buffet restaurant', 'Food court', 'Cafeteria', 'Irish pub', 'English restaurant', 'Scottish restaurant', 'Pub', 'Brewpub',
 'Wine bar', 'Cocktail bar', 'Sports bar', 'Juice shop', 'Smoothie shop', 'Tea house']

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df6= df6.dropna(subset=['category']).loc[df6['category'].astype(bool)]
filtered_df6 = df6[df6['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df6 = filtered_df6.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
filtered_df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 797 entries, 278 to 274883
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            797 non-null    object
#  1   address         797 non-null    object
#  2   gmap_id         797 non-null    object
#  3   latitude        797 non-null    float64
#  4   longitude       797 non-null    float64
#  5   category        797 non-null    object
#  6   avg_rating      797 non-null    float64
#  7   num_of_reviews  797 non-null    int64
#  8   MISC            789 non-null    object
#  9   state           706 non-null    object
#  10  estado          797 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 74.7+ KB

# %% [markdown]
# ##

# %% [markdown]
# # 7

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/7.json'
df7 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df7['estado'] = df7['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df7 = df7[df7['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df7_exploded = df7.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df7_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
print(segunda_mitad)
# Out:
# ['Pet groomer', 'Travel agency', 'Cruise agency', 'Tourist information center', 'Wholesale bakery', 'Religious goods store', 'Real estate agents', 'Roofing contractor', "Women's clothing store", 'Religious school', 'Pharmacy', 'Farm', 'Cabinet maker', 'Electrician', 'Rehabilitation center', 'Medical Center', 'Paving contractor', 'Florist', 'Air conditioning repair service', 'Air duct cleaning service', 'HVAC contractor', 'Used car dealer', 'Auto body shop', 'Auto dent removal service', 'Auto repair shop', 'Landscaper', 'Lawn care service', 'Doctor', 'Real estate developer', 'Pest control service', 'Association or organization', 'Restaurant', 'American restaurant', 'Barbecue restaurant', 'Hamburger restaurant', 'Pub', 'Sandwich shop', 'Taco restaurant', 'Tex-Mex restaurant', 'Vegan restaurant', 'Vegetarian restaurant', 'Eye care center', 'Contact lenses supplier', 'Optician', 'Optometrist', 'Sunglasses store', 'Day spa', 'Massage spa', 'Remodeler', 'Harbor', 'Internet cafe', 'Art gall
# ...

# %%
categorias_gastronomicas = [
    'Restaurant', 'American restaurant', 'Barbecue restaurant', 'Hamburger restaurant', 'Sandwich shop',
    'Taco restaurant', 'Tex-Mex restaurant', 'Vegan restaurant', 'Vegetarian restaurant', 'Thai restaurant', 'Bakery',
    'Cake shop', 'Candle store', 'Deli', 'French restaurant', 'Breakfast restaurant', 'Donut shop', 'Italian restaurant',
    'Pasta shop', 'Japanese restaurant', 'Ethiopian restaurant', 'Dominican restaurant', 'Puerto Rican restaurant',
    'Chicken restaurant', 'Jamaican restaurant', 'Mediterranean restaurant', 'South Asian restaurant', 'Falafel restaurant',
    'Middle Eastern restaurant', 'Diner', 'Mexican restaurant', 'Fast food restaurant', 'Pizza restaurant', 'Sushi restaurant',
    'Cuban restaurant', 'Honduran restaurant', 'Peruvian restaurant', 'Seafood restaurant', 'Juice shop', 'Health food restaurant',
    'Organic restaurant', 'Soup restaurant', 'Fine dining restaurant', 'Southern restaurant (US)', 
    'Seafood market'
]

# %%
categorias_gastronomicas1 = [
    'Restaurant', 'American restaurant', 'Barbecue restaurant', 'Hamburger restaurant', 'Sandwich shop',
    'Taco restaurant', 'Tex-Mex restaurant', 'Vegan restaurant', 'Vegetarian restaurant', 'Thai restaurant', 'Bakery',
    'Cake shop', 'Candle store', 'Deli', 'French restaurant', 'Breakfast restaurant', 'Donut shop', 'Italian restaurant',
    'Pasta shop', 'Japanese restaurant', 'Ethiopian restaurant', 'Dominican restaurant', 'Puerto Rican restaurant',
    'Chicken restaurant', 'Jamaican restaurant', 'Mediterranean restaurant', 'South Asian restaurant', 'Falafel restaurant',
    'Middle Eastern restaurant', 'Diner', 'Mexican restaurant', 'Fast food restaurant', 'Pizza restaurant', 'Sushi restaurant',
    'Cuban restaurant', 'Honduran restaurant', 'Peruvian restaurant', 'Seafood restaurant', 'Juice shop', 'Health food restaurant',
    'Organic restaurant', 'Soup restaurant', 'Fine dining restaurant', 'Southern restaurant (US)', 
    'Seafood market'
]

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df7= df7.dropna(subset=['category']).loc[df7['category'].astype(bool)]
filtered_df7 = df7[df7['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df7 = filtered_df7.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %% [markdown]
# # 8

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/8.json'
df8 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df8['estado'] = df8['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df8 = df8[df8['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df8_exploded = df8.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df8_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
print(segunda_mitad)
# Out:
# ['Chiropractor', 'Mover', 'Fast food restaurant', 'Restaurant', 'Pizza restaurant', 'Pizza delivery', 'Pizza Takeout', 'Pharmacy', 'Medical Center', 'Medical supply store', 'Hot dog restaurant', 'Dentist', 'Endodontist', 'Digital printing service', 'Sign shop', 'Airport parking lot', 'Bridge', 'Animal hospital', 'Florist', 'Park', 'Software company', 'Electrical engineer', 'Engineer', 'Apartment complex', 'Apartment building', 'Perfume store', 'Clothing store', 'Fashion accessories store', 'Shoe store', 'Air filter supplier', 'Air conditioning contractor', 'Air duct cleaning service', 'Hotel', 'Plumber', 'Cleaning service', 'Bar & grill', 'Cafe', 'Italian restaurant', 'Pizza takeaway', 'Cell phone store', 'Electronic parts supplier', 'Electronics store', 'Telephone company', 'Home goods store', 'Pediatrician', 'Seafood restaurant', 'American restaurant', 'Angler fish restaurant', 'Bar', 'Crab house', 'Event venue', 'Family restaurant', 'Buick dealer', 'GMC dealer', 'Internet service 
# ...

# %%
categorias_gastronomicas = [
    'Fast food restaurant', 'Restaurant', 'Pizza restaurant',
    'Pizza delivery', 'Pizza Takeout', 'Hot dog restaurant',
    'Italian restaurant', 'Seafood restaurant', 'American restaurant',
    'Cafe', 'Bar & grill', 'Bar', 'Crab house', 'Family restaurant',
    'Cuban restaurant', 'Hamburger restaurant', 'Mexican restaurant',
    'Japanese restaurant', 'Sushi restaurant', 'Caribbean restaurant',
    'Jamaican restaurant', 'Peruvian restaurant', 'Asian restaurant',
    'Chinese restaurant', 'South Asian restaurant', 'Vegan restaurant',
    'Vegetarian restaurant', 'Chicken restaurant', 'Latin American restaurant',
    'Southern Italian restaurant', 'Puerto Rican restaurant', 'Creole restaurant',
    'Brazilian restaurant', 'Pan-Asian restaurant', 'Tex-Mex restaurant',
    'Southwestern restaurant (US)', 'Burrito restaurant', 'Southeast Asian restaurant',
    'Thai restaurant', 'Sightseeing tour agency', 'African restaurant',
    'Mongolian barbecue restaurant',
]

# %%
categorias_gastronomicas1 = [
    'Fast food restaurant', 'Restaurant', 'Pizza restaurant',
    'Italian restaurant', 'Seafood restaurant', 'American restaurant',
    'Cafe', 'Bar & grill', 'Bar', 'Hamburger restaurant', 'Mexican restaurant',
    'Japanese restaurant', 'Sushi restaurant', 'Asian restaurant',
    'Chinese restaurant', 'Vegan restaurant', 'Vegetarian restaurant',
    'Chicken restaurant', 'Latin American restaurant', 'Brazilian restaurant',
    'Tex-Mex restaurant', 'Thai restaurant', 'African restaurant',
    'Mongolian barbecue restaurant', 'Cheesesteak restaurant', 'Crab house',
    'Peruvian restaurant', 'Caribbean restaurant', 'Jamaican restaurant',
    'Creole restaurant', 'Puerto Rican restaurant', 'Pan-Asian restaurant',
    'South Asian restaurant', 'Southeast Asian restaurant', 'Korean restaurant',
    'Vietnamese restaurant', 'Argentinian restaurant', 'Soul food restaurant',
    'Northern Italian restaurant', 'Nuevo Latino restaurant', 'Oyster bar restaurant',
    'Polynesian restaurant', 'Dim sum restaurant', 'Brasserie', 'Sicilian restaurant',
    'Floridian restaurant', 'Modern Indian restaurant', 'Tapas restaurant',
    'Halal restaurant', 'Pakistani restaurant', 'Bangladeshi restaurant'
]

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df8= df8.dropna(subset=['category']).loc[df8['category'].astype(bool)]
filtered_df8 = df8[df8['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df8 = filtered_df8.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
filtered_df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2485 entries, 24 to 274795
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2485 non-null   object
#  1   address         2485 non-null   object
#  2   gmap_id         2485 non-null   object
#  3   latitude        2485 non-null   float64
#  4   longitude       2485 non-null   float64
#  5   category        2485 non-null   object
#  6   avg_rating      2485 non-null   float64
#  7   num_of_reviews  2485 non-null   int64
#  8   MISC            2466 non-null   object
#  9   state           2330 non-null   object
#  10  estado          2485 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 233.0+ KB

# %% [markdown]
# # 9

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/9.json'
df9 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df9['estado'] = df9['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df9 = df9[df9['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df9_exploded = df9.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df9_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
print(segunda_mitad)
# Out:
# ['Grocery store', 'Auto parts store', 'Dentist', 'Campground', 'Government office', 'Association or organization', 'American restaurant', 'Beauty salon', 'School', 'Medical clinic', 'Car dealer', 'Auto broker', 'Used car dealer', 'Nail salon', 'Church', 'Dry cleaner', 'Clothing alteration service', 'Laundry service', 'Pharmacy', 'Baptist church', 'Gas station', 'Condominium complex', 'Apartment complex', 'Newspaper publisher', 'Media company', 'Bank', 'ATM', 'Home goods store', 'Appliance store', 'Commercial printer', 'Life insurance agency', 'Tanning salon', 'Auto repair shop', 'Cell phone store', 'Computer repair service', 'Computer store', 'Electronics repair shop', 'Used computer store', 'Car leasing service', 'Used truck dealer', 'Boat rental service', 'Plumber', 'Air conditioning contractor', 'Hair salon', 'Stylist', 'Roofing contractor', 'Electronic parts supplier', 'Electronics store', 'Telephone company', 'Trailer supply store', 'Truck accessories store', 'Truck repair shop'
# ...

# %%
categorias_gastronomicas = [
    'American restaurant', 'Asian grocery store', 'Latin American restaurant', 'Pho restaurant', 'Sushi restaurant', 'Bubble tea store',
    'Mexican grocery store', 'Thai restaurant', 'Butcher shop', 'Asian fusion restaurant', 'Gourmet grocery store', 'Bakery',
    'Cafe', 'Restaurant', 'Sandwich shop', 'Deli', 'Chinese restaurant', 'Japanese restaurant', 'New American restaurant',
    'Wine bar', 'Vietnamese restaurant', 'Fast food restaurant', 'Gluten-free restaurant', 'Liquor store', 'Pizza restaurant',
    'Seafood market', 'Seafood wholesaler', 'Italian restaurant', 'Cheesesteak restaurant', 'Steak house', 'French restaurant',
    'Mediterranean restaurant', 'European restaurant', 'Greek restaurant', 'Vegan restaurant', 'Small plates restaurant',
    'Chicken wings restaurant', 'Sports bar', 'Spanish restaurant', 'Seafood restaurant', 'Chicken restaurant', 'Tapas restaurant',
    'Açaí shop', 'Charcuterie', 'Soul food restaurant', 'Bistro'
]

# %%
categorias_gastronomicas1 = [
    'Vegetarian restaurant', 'Pasta shop', 'Hat shop', 'Taco restaurant', 'Sushi takeaway', 'Bakery',
    'Food bank', 'Bistro', 'Brewery', 'Pizzeria', 'Coffee shop', 'Ice cream shop',
    'Dessert restaurant', 'Catering', 'Barbecue area', 'Gastropub', 'Fruit parlor', 'Soup restaurant',
    'Cafe', 'Smoothie shop', 'Tapas bar', 'Wine bar', 'Donut shop', 'Sandwich shop',
    'Tea store', 'Deli', 'Butcher shop', 'Cheese shop', 'Burger restaurant', 'Seafood restaurant',
    'Steak house', 'Buffet restaurant', 'Diner', 'Hot dog restaurant', 'Food truck', 'Salad shop',
    'Noodle shop', 'Fish and chips restaurant', 'Creperie', 'Bagel shop', 'Juice shop',
    'Cupcake shop', 'Sake brewery', 'Oyster bar restaurant', 'Cajun restaurant', 'Dim sum restaurant',
    'Ramen restaurant', 'Cheesesteak restaurant', 'Doughnut shop', 'Mediterranean restaurant', 'Pastry shop',
    
]

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df9= df9.dropna(subset=['category']).loc[df9['category'].astype(bool)]
filtered_df9 = df9[df9['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df9 = filtered_df9.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
filtered_df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1765 entries, 213 to 274768
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1765 non-null   object
#  1   address         1765 non-null   object
#  2   gmap_id         1765 non-null   object
#  3   latitude        1765 non-null   float64
#  4   longitude       1765 non-null   float64
#  5   category        1765 non-null   object
#  6   avg_rating      1765 non-null   float64
#  7   num_of_reviews  1765 non-null   int64
#  8   MISC            1745 non-null   object
#  9   state           1600 non-null   object
#  10  estado          1765 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 165.5+ KB

# %% [markdown]
# # 10

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/10.json'
df10 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df10['estado'] = df10['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df10 = df10[df10['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df10_exploded = df10.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df10_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
print(segunda_mitad)
# Out:
# ['Souvenir store', 'Used car dealer', 'Hospice', 'Store', 'Thrift store', 'Property management company', 'Dentist', 'Cosmetic dentist', 'Dental implants periodontist', 'Denture care center', 'Endodontist', 'Oral surgeon', 'Orthodontist', 'Periodontist', 'Teeth whitening service', 'Auto repair shop', 'Beauty salon', 'Internist', 'Medical group', 'Book store', 'Insurance agency', 'Auto insurance agency', 'Home insurance agency', 'Motorcycle insurance agency', 'Health food store', 'Fruit and vegetable store', 'Bookkeeping service', "Women's clothing store", 'Shoe store', 'Animal rescue service', 'Gym', 'Boot camp', 'Fitness center', 'Physical fitness program', 'Lawn sprinkler system contractor', 'Self-storage facility', 'Moving and storage service', 'Moving supply store', 'Storage facility', 'Chiropractor', 'Massage therapist', 'Physical therapist', 'Bait shop', 'Nail salon', 'Tire shop', 'Oil change service', 'Towing service', 'Trailer supply store', 'RV storage facility', 'Trailer ren
# ...

# %%
categorias_gastronomicas = [
    'Vegetarian restaurant', 'Pasta shop', 'Taco restaurant', 'Sushi takeaway', 'Bakery', 'Bistro',
    'Pizzeria', 'Coffee shop', 'Ice cream shop', 'Dessert restaurant', 'Catering', 'Gastropub',
    'Fruit parlor', 'Soup restaurant', 'Cafe', 'Smoothie shop', 'Tapas bar', 'Wine bar', 'Donut shop',
    'Sandwich shop', 'Tea store', 'Deli', 'Burger restaurant', 'Seafood restaurant', 'Steak house',
    'Buffet restaurant', 'Diner', 'Hot dog restaurant', 'Salad shop', 'Noodle shop', 'Fish and chips restaurant',
    'Creperie', 'Bagel shop', 'Juice shop', 'Cupcake shop', 'Sake brewery', 'Oyster bar restaurant',
    'Cajun restaurant', 'Dim sum restaurant', 'Ramen restaurant', 'Cheesesteak restaurant', 'Mediterranean restaurant',
    'Pastry shop', 'Irish pub', 'Pizza restaurant', 'Caribbean restaurant', 'Jamaican restaurant', 'Italian restaurant',
    'Dominican restaurant', 'Takeout Restaurant', 'Puerto Rican restaurant', 'Greek restaurant', 'Vitamin & supplements store',
]

# %%
categorias_gastronomicas1 = [
    'Argentinian restaurant', 'Brazilian restaurant', 'Dessert restaurant', 'Sushi takeaway', 'Tapas restaurant', 'Southern restaurant (US)',
    'Bistro', 'Cafeteria', 'Steak house', 'Tapas restaurant', 'Diner', 'Doughnut shop',
    'Breakfast restaurant', 'Buffet restaurant', 'Bakery', 'Pizza delivery', 'Ice cream shop', 'Coffee shop',
    'Tea house', 'Juice shop', 'Bakery', 'Pizza delivery', 'Ice cream shop', 'Coffee shop',
    'Tea house', 'Juice shop', 'Bakery', 'Candy store', 'Cheese shop', 'Butcher shop',
    'Fish market', 'Seafood market', 'Health food restaurant', 'Vegetarian restaurant', 'Vegan restaurant', 'Salad bar',
    'Soup restaurant', 'Sandwich shop', 'Bagel shop', 'Hot dog stand', 'Burrito restaurant', 'Taco restaurant',
    'Mexican restaurant', 'Brazilian restaurant'
]

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df10= df10.dropna(subset=['category']).loc[df10['category'].astype(bool)]
filtered_df10 = df10[df10['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df10 = filtered_df10.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
filtered_df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1346 entries, 978 to 274838
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1346 non-null   object
#  1   address         1346 non-null   object
#  2   gmap_id         1346 non-null   object
#  3   latitude        1346 non-null   float64
#  4   longitude       1346 non-null   float64
#  5   category        1346 non-null   object
#  6   avg_rating      1346 non-null   float64
#  7   num_of_reviews  1346 non-null   int64
#  8   MISC            1339 non-null   object
#  9   state           1257 non-null   object
#  10  estado          1346 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 126.2+ KB

# %% [markdown]
# # 11

# %%
# Importar el nuevo DataFrame (df4)
ruta_al_archivo = 'Google/metadata-sitios/11.json'
df11 = pd.read_json(ruta_al_archivo, lines=True, encoding='utf-8')
# Añadir la columna 'estado' al DataFrame df4
df11['estado'] = df11['address'].str.extract(r',\s([A-Z]{2})\s\d{5}')
# Filtrar df4 para quedarse solo con los datos de Florida (estado == 'FL')
df11 = df11[df11['estado'] == 'FL']
# Explodir la columna 'category' en el DataFrame df4
df11_exploded = df11.explode('category')
# Obtener los valores únicos de la columna 'category' después de la explosión
categorias_distintas_exploded = df11_exploded['category'].unique().tolist()
# Calcular la mitad del tamaño de la lista
mitad = len(categorias_distintas_exploded) // 2
# Dividir la lista en dos partes
primera_mitad = categorias_distintas_exploded[:mitad]
segunda_mitad = categorias_distintas_exploded[mitad:]

# %%
print(primera_mitad)
print(segunda_mitad)
# Out:
# ['Horse boarding stable', 'Beauty salon', 'Walk-in clinic', 'Health consultant', 'Medical clinic', 'Medical office', 'Medical spa', 'Nutritionist', 'Pain management physician', 'Reproductive health clinic', 'Weight loss service', 'Pediatric dentist', 'Dental clinic', 'Dentist', 'Emergency dental service', 'Orthodontist', 'Veterinarian', 'Forensic consultant', 'Veterinary care', 'Animal hospital', 'Hospital', 'Shopping mall', 'Bakery', 'Pet groomer', 'Chiropractor', 'Acupuncture clinic', 'Massage therapist', 'X-ray lab', 'Nail salon', 'Hypnotherapy service', 'Life coach', 'Meditation center', 'Plant nursery', 'Car stereo store', 'Cosmetic dentist', 'Dental implants periodontist', 'Laboratory', 'Oral surgeon', 'Corporate office', 'Tropical fish store', 'Podiatrist', 'Chocolate shop', 'Self-storage facility', 'Automobile storage facility', 'Boat storage facility', 'Moving supply store', 'RV storage facility', 'Storage facility', 'Oil change service', 'Brake shop', 'Tire shop', 'Muffler 
# ...

# %%
categorias_gastronomicas = [
    'Argentinian restaurant', 'Brazilian restaurant', 'Dessert restaurant', 'Sushi takeaway', 'Tapas restaurant', 'Southern restaurant (US)',
    'Bistro', 'Cafeteria', 'Steak house', 'Tapas restaurant', 'Diner', 'Doughnut shop',
    'Breakfast restaurant', 'Buffet restaurant', 'Bakery', 'Pizza delivery', 'Ice cream shop', 'Coffee shop',
    'Tea house', 'Juice shop', 'Bakery', 'Pizza delivery', 'Ice cream shop', 'Coffee shop',
    'Tea house', 'Juice shop', 'Bakery', 'Candy store', 'Cheese shop', 'Butcher shop',
    'Fish market', 'Seafood market', 'Health food restaurant', 'Vegetarian restaurant', 'Vegan restaurant', 'Salad bar',
    'Soup restaurant', 'Sandwich shop', 'Bagel shop', 'Hot dog stand', 'Burrito restaurant', 'Taco restaurant',
    'Mexican restaurant', 'Brazilian restaurant', 'Horse boarding stable', 'Pizza restaurant', 'Pizza Takeout', 'Takeout Restaurant', 'Delivery Restaurant'
]
categorias_gastronomicas1 = [
    'Seafood wholesaler', 'Food court', 'Crab house',
    'Asian fusion restaurant', 'Nicaraguan restaurant', 'Brazilian restaurant',
    'South American restaurant', 'Quilt shop', 'Brazilian restaurant',
    'Asian fusion restaurant', 'Nicaraguan restaurant', 'Brazilian restaurant',
    'South American restaurant', 'Audio visual equipment supplier', 'Organic drug store',
    'Boot store', 'Helicopter charter', 'Mobile caterer', 'Noodle shop', 'Christmas store',
    'Aquaculture farm', 'Fish farm', 'Fish store', 'Catering', 'Pho restaurant', 'Tea store',
    'Korean torta restaurant', 'Creole restaurant', 'Greek Orthodox church', 'Austrian restaurant',
    'Halfway house', 'Rubber products supplier', 'Small plates restaurant', 'Kebab shop',
    'Brazilian pastelaria', 'Sushi takeaway', 'Kosher grocery store', 'Pretzel store',
    'Japanese steakhouse', 'Hot pot restaurant', 'Crêperie', 'Traditional American restaurant',
    'Distillery', 'Wine cellar', 'Japanese curry restaurant', 'Ramen restaurant',
    'Mexican grocery store', 'Argentinian restaurant', 'Turkish restaurant', 'Churreria'
]

# %%
categorias_gastronomicas_filtradas=categorias_gastronomicas+categorias_gastronomicas1
df11= df11.dropna(subset=['category']).loc[df11['category'].astype(bool)]
filtered_df11 = df11[df11['category'].apply(lambda x: any(item in x for item in categorias_gastronomicas_filtradas))]
filtered_df11 = filtered_df11.drop(['description', 'price', 'hours', 'relative_results', 'url'], axis=1)

# %%
filtered_df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1420 entries, 8 to 274970
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1420 non-null   object
#  1   address         1420 non-null   object
#  2   gmap_id         1420 non-null   object
#  3   latitude        1420 non-null   float64
#  4   longitude       1420 non-null   float64
#  5   category        1420 non-null   object
#  6   avg_rating      1420 non-null   float64
#  7   num_of_reviews  1420 non-null   int64
#  8   MISC            1399 non-null   object
#  9   state           1338 non-null   object
#  10  estado          1420 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 133.1+ KB

# %%
dfs = [df1_filtered, filtered_df2, filtered_df3, filtered_df4, filtered_df5,
       filtered_df6, filtered_df7, filtered_df8, filtered_df9, filtered_df10, filtered_df11]

# Concatenar verticalmente los DataFrames
metadata_FL_Google = pd.concat(dfs, ignore_index=True)

# %%
metadata_FL_Google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15300 entries, 0 to 15299
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            15300 non-null  object
#  1   address         15300 non-null  object
#  2   gmap_id         15300 non-null  object
#  3   latitude        15300 non-null  float64
#  4   longitude       15300 non-null  float64
#  5   category        15300 non-null  object
#  6   avg_rating      15300 non-null  float64
#  7   num_of_reviews  15300 non-null  int64
#  8   MISC            15049 non-null  object
#  9   state           13578 non-null  object
#  10  estado          15300 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
metadata_FL_Google.head()
# Out:
#                          name  \
# 0          Cape Seafood Shack
# 1  Fresh Point Country Buffet
# 2             Oneyda's Bakery
# 3         Annie's Bake Shoppe
# 4       Tropical Park Liquors
#
#                                              address  \
# 0  Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 1  Fresh Point Country Buffet, 10525 US-19, Pinel...
# 2  Oneyda's Bakery, 600 Goodlette-Frank Rd #101, ...
# 3  Annie's Bake Shoppe, 10331 SW 54th St, Miami, ...
# 4  Tropical Park Liquors, 7971 SW 40th St Suite #...
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88db4147b1d9e6f3:0x943dbd10a92ba1b1  26.641377 -81.940545
# 1  0x88c2e4e34f1ed783:0x76c5da381c499d79  27.867489 -82.702971
# 2  0x88dae191ee505917:0x6ba3e25388d3fad4  26.154754 -81.790528
# 3  0x88d9c754413f6c9d:0x1f93eff5e0ba9c16  25.717416 -80.361945
# 4  0x88d9b99475d9fd7b:0xea6083d207b2471a  25.733914 -80.325216
#
#                       category  avg_rating  num_of_reviews  \
# ...

# %%
metadata_FL_Google.to_json('metadata_FL_Google.json', orient='records')
