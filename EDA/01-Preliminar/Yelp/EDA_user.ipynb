# %% [markdown]
# # EDA y ETL user

# %% [markdown]
#  Data del usuario incluyendo referencias a otros usuarios amigos y a toda la metadata asociada al usuario.

# %%
import pandas as pd

# %%
df = pd.read_parquet("c:/Users/leand/Desktop/Proyecto Final/Yelp/Datasets Yelp/user.parquet")

# %%
df.head()
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
df.shape
# Out:
# (1987897, 22)

# %% [markdown]
# ### Vemos si tenemos duplicados en el user_id

# %%
# Contar la cantidad total de duplicados en la columna 'business_id'
cantidad_duplicados = df['user_id'].duplicated().sum()

# Mostrar la cantidad total de duplicados
print("Cantidad total de duplicados en la columna 'user_id':", cantidad_duplicados)
# Out:
# Cantidad total de duplicados en la columna 'user_id': 117700

# %% [markdown]
# ### Eliminamos duplicados

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1987897, 22)

# %% [markdown]
# En total fueron eliminadas 117700 filas

# %% [markdown]
# ### Hacemos un top 5 de usuarios con mas reseñas

# %%
# Utiliza nlargest para obtener el top 5
top_5_review = df.nlargest(5, 'review_count')
top_5_review
# Out:
#                        user_id    name  review_count        yelping_since  \
# 17169   Hi10sGSZNxQH3NLyWSZ1oA     Fox         17473  2009-05-26 11:33:58
# 795339  8k3aO-mPeyhbR5HUucA5aA  Victor         16978  2007-12-08 14:56:45
# 4723    hWDybu_KvYLSdEFzGrniTw   Bruce         16567  2009-03-08 21:47:44
# 606393  RtGqdDBvvBCjcu5dUqwfzA   Shila         12868  2010-10-17 06:35:06
# 152     P5bUL3Engv-2z6kKohB6qQ     Kim          9941  2006-05-31 21:27:42
#
#         useful   funny    cool  \
# 17169   206296  185823  195814
# 795339  152979   84992  125516
# 4723    173089   98459  144849
# 606393   11109    3747    3292
# 152      27549   10772   21375
#
#                                                     elite  \
# 17169            2014,2015,2016,2017,2018,2019,20,20,2021
# 795339  2008,2009,2010,2011,2012,2013,2014,2015,2016,2...
# 4723    2010,2011,2012,2013,2014,2015,2016,2017,2018,2...
# 606393  2012,2013,2014,2015,2016,2017,2018,2019,20,20,...
# ...

# %%
print(top_5_review["average_stars"])
# Out:
# 17169     3.77
# 795339    3.35
# 4723      3.67
# 606393    3.87
# 152       3.81
# Name: average_stars, dtype: float64

# %% [markdown]
# ### Hacemos un top 5 de usuarios con mas fans

# %%
# Utiliza nlargest para obtener el top 5
top_5_fans = df.nlargest(5, 'fans')
top_5_fans
# Out:
#                        user_id     name  review_count        yelping_since  \
# 5444    37cpUoM8hlkSQfReIEBd-Q     Mike          1882  2009-04-25 14:54:26
# 198889  hizGc5W1tBHPghM5YKCAtg    Katie          1825  2009-05-22 20:19:55
# 17169   Hi10sGSZNxQH3NLyWSZ1oA      Fox         17473  2009-05-26 11:33:58
# 200787  JjXuiru1_ONzDkYVrHN0aw  Richard          1424  2009-08-23 13:03:27
# 1       j14WgRoU_-2ZE1aw1dXrJg   Daniel          4333  2009-01-25 04:35:42
#
#         useful   funny    cool  \
# 5444     22860   10965   15350
# 198889   48711   32078   39747
# 17169   206296  185823  195814
# 200787  183512  129638  173423
# 1        43091   13066   27281
#
#                                                     elite  \
# 5444    2012,2013,2014,2015,2016,2017,2018,2019,20,20,...
# 198889  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 17169            2014,2015,2016,2017,2018,2019,20,20,2021
# 200787  2011,2012,2013,2014,2015,2016,2017,2018,2019,2...
# ...

# %% [markdown]
# ### Vemos el promedio de los que mas fans tienen

# %%
print(top_5_fans["average_stars"])
# Out:
# 5444      4.39
# 198889    4.23
# 17169     3.77
# 200787    4.18
# 1         3.74
# Name: average_stars, dtype: float64
